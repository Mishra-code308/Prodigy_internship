# %% [markdown]
# <a href="https://colab.research.google.com/github/Mishra-code308/Prodigy_internship/blob/main/Untitled70.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 4

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
df=pd.read_csv('/content/twitter_training.csv (1).zip')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74681 entries, 0 to 74680
# Data columns (total 4 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   2401                                                   74681 non-null  int64
#  1   Borderlands                                            74681 non-null  object
#  2   Positive                                               74681 non-null  object
#  3   im getting on borderlands and i will murder you all ,  73995 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 2.3+ MB

# %%
df.head()
# Out:
#    2401  Borderlands  Positive  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#   im getting on borderlands and i will murder you all ,
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %%
# Inspect how many columns are there
print("Number of columns:", df.shape[1])
df.head()
# Out:
# Number of columns: 4
#      id       entity sentiment  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#                                              content
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %%
df.columns = ['id', 'entity', 'sentiment', 'content']
df.head()
# Out:
#      id       entity sentiment  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#                                              content
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %%
sns.countplot(x='sentiment', data=df, hue='sentiment', palette='viridis', legend=False)

plt.title("Sentiment Distribution")
plt.xlabel('sentiment')
plt.ylabel('count')
plt.show()

# %%
# Count the frequency of each entity
top_entities = df['entity'].value_counts().head(10)

# Display as a bar chart
top_entities.plot(kind='bar', color='pink')
plt.title("Top 10 Most Mentioned Entities")
plt.xlabel("Entity")
plt.ylabel("Number of Mentions")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
from wordcloud import WordCloud

positive_text = ' '.join(df[df['sentiment'] == 'Positive']['content'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(positive_text)

plt.figure(figsize=(15, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('WordCloud - Positive Tweets')
plt.show()

# %%
from collections import Counter

positive_words = ' '.join(df[df['sentiment'] == 'Positive']['content']).split()
counter = Counter(positive_words)
print(counter.most_common(20))
# Out:
# [('the', 10163), ('I', 8011), ('to', 7501), ('and', 6458), ('a', 5480), ('of', 4962), ('is', 4190), ('for', 4156), ('in', 3525), ('this', 2969), ('my', 2812), ('it', 2734), ('on', 2580), ('.', 2528), ('@', 2371), ('/', 2369), ('that', 2134), ('with', 2069), ('so', 2052), ('you', 2007)]

# %%
# Clean the 'content' column by filling missing values with empty strings and converting to string type
df['content'] = df['content'].fillna('').astype(str)
